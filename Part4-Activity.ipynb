# %%
import starter_code as starter_code
# %matplotlib inline
from starter_code import custom_run
custom_run()

# %%
import starter_code as starter_code
# %matplotlib inline
from starter_code import custom_run
# window_sizes = [5, 10, 15]
pairs = [(5, 2), (10, 3), (15, 5)]
# strides = [2, 3, 5]
# for w_size in window_sizes:
#     for stryd in strides:
for pair in pairs:
    custom_run(False, "FullBodySensors", pair[0], pair[1])
# Out:
# Loading Dataset...
# Done...
# Activity labels
# Training...
# Window Size: 5, stride:2
# Subject:  S1
# Classifier: GradientBoostingClassifier.
# Training...  317361
#       Iter       Train Loss   Remaining Time
#          1      503412.0392           45.55m
#          2      440933.3327           44.41m
#          3      394713.1022           43.61m
#          4      358909.6907           43.01m
#          5      329057.2712           42.38m
#          6      304207.5711           41.83m
#          7      283614.2828           41.29m
#          8      265658.6112           40.78m
#          9      250579.2112           40.23m
#         10      238261.6643           39.64m
#         20      166034.1671           34.07m
#         30      136686.6330           28.39m
#         40      119384.9157           22.36m
#         50      107426.5606           16.22m
#         60       97969.9385           10.53m
#         70       90899.0321            5.16m
# ...
