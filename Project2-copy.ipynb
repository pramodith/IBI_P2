# %%
import starter_code as starter_code
# %matplotlib inline
from starter_code import custom_run
custom_run()
# Out:
# Window Sizes: [5, 10, 15], Strides: [2, 3, 5]
#
# Window Size: 5, stride:2
#
# Normalized confusion matrix
# [[6.28067617e-01 1.77408991e-01 1.78434619e-02 1.69463460e-01
#   7.21646937e-03]
#  [2.87535689e-02 8.68456034e-01 5.12073609e-03 9.76581013e-02
#   1.15592237e-05]
#  [1.44234985e-02 6.94432267e-02 9.06108432e-01 9.99561596e-03
#   2.92269472e-05]
#  [8.53738116e-02 2.65106567e-01 3.66432752e-03 6.45855294e-01
#   0.00000000e+00]
#  [2.10443412e-01 2.93455147e-01 3.39450264e-02 1.96109317e-02
#   4.42545483e-01]]
# Weighted F-Score: 0.7625712620158603
# Window Size: 5, stride:3
# Normalized confusion matrix
# [[6.20781050e-01 1.82455100e-01 1.85161159e-02 1.72835616e-01
#   5.41211795e-03]
#  [2.94222184e-02 8.67808071e-01 6.41497984e-03 9.61293399e-02
#   2.25391184e-04]
#  [1.15728564e-02 7.34043486e-02 9.05597931e-01 9.35910924e-03
#   6.57548659e-05]
#  [8.39383077e-02 2.64391361e-01 3.72021568e-03 6.47814562e-01
#   1.35554418e-04]
# ...
